# %%
import numpy as np
import pandas as pd
import plotnine as gg

from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

# %%
df = pd.read_csv('../data/engineered_factset_campaign_data.csv', parse_dates=[
    '18_months_pre_announcement_date',
    '1_year_pre_announcement_date',
    '6_months_pre_announcement_date',
    '90_days_pre_announcement_date',
    'campaign_announcement_date',
    '6_months_post_announcement_date',
    '1_year_post_announcement_date',
    '18_months_post_announcement_date'
])

df_model_data = (
    df
    .assign(objective=lambda df: df.campaign_objective_group)
    .assign(result=lambda df: df.proxy_campaign_winner_or_result)
    .assign(post_return=lambda df: df['1_year_post_date_total_return_category'])
)

# %%
df_model_data.groupby(['objective'])['1_year_post_date_total_return'].mean()
# Out:
# objective
# Board Add          0.056824
# Board Remove      -0.078587
# ESG                0.039628
# Merger             0.024228
# Value Long         0.059467
# Value Short       -0.018855
# Vote Dissident     0.083221
# Vote Management    0.069163
# Name: 1_year_post_date_total_return, dtype: float64

# %%
model = BayesianModel([
    ('objective', 'post_return')
])

model.fit(
    df_model_data,
    estimator=BayesianEstimator,
    complete_samples_only=False
)

for cpd in model.get_cpds():
    print("CPD of {variable}:".format(variable=cpd.variable))
    print(cpd)
# Out:
# CPD of objective:
# +----------------------------+-----------+
# | objective(Board Add)       | 0.351157  |
# +----------------------------+-----------+
# | objective(Board Remove)    | 0.0176232 |
# +----------------------------+-----------+
# | objective(ESG)             | 0.032527  |
# +----------------------------+-----------+
# | objective(Merger)          | 0.13445   |
# +----------------------------+-----------+
# | objective(Value Long)      | 0.249835  |
# +----------------------------+-----------+
# | objective(Value Short)     | 0.0211088 |
# +----------------------------+-----------+
# | objective(Vote Dissident)  | 0.180844  |
# +----------------------------+-----------+
# | objective(Vote Management) | 0.0124549 |
# +----------------------------+-----------+
# CPD of post_return:
# +--------------------------+----------------------+-------------------------+--------------------+---------------------+-----------------------+------------------------+---------------------------+----------------------------+
# | objective                | objective(Board Add) | objective(Board Remove) | objective(ESG)     | objective(Merger)   | objective(Value Long) | objective(Value Short) | objective(Vote Dissident) | objective(Vote Management) |
# +--------------------------+----------------------+-------------------------+--------------------+---------------------+-----------------------+------------------------+---------------------------+----------------------------+
# | post_return((-1.0, 0.0]) | 0.5356295788752438   | 0.6243523316062176      | 0.5085975282106394 | 0.5209233568342051  | 0.5161227811797535    | 0.5504334121355398     | 0.41538967754066          | 0.4364069952305246         |
# +--------------------------+----------------------+-------------------------+--------------------+---------------------+-----------------------+------------------------+---------------------------+----------------------------+
# | post_return((0.0, 1.0])  | 0.46437042112475624  | 0.3756476683937824      | 0.4914024717893606 | 0.47907664316579485 | 0.4838772188202465    | 0.4495665878644602     | 0.5846103224593401        | 0.5635930047694754         |
# +--------------------------+----------------------+-------------------------+--------------------+---------------------+-----------------------+------------------------+---------------------------+----------------------------+

# %%
model = BayesianModel([
    ('objective', 'result'),
    ('result', 'post_return')
])

model.fit(
    df_model_data,
    estimator=BayesianEstimator,
    complete_samples_only=False
)

for cpd in model.get_cpds():
    print("CPD of {variable}:".format(variable=cpd.variable))
    print(cpd)
# Out:
# CPD of objective:
# +----------------------------+-----------+
# | objective(Board Add)       | 0.351157  |
# +----------------------------+-----------+
# | objective(Board Remove)    | 0.0176232 |
# +----------------------------+-----------+
# | objective(ESG)             | 0.032527  |
# +----------------------------+-----------+
# | objective(Merger)          | 0.13445   |
# +----------------------------+-----------+
# | objective(Value Long)      | 0.249835  |
# +----------------------------+-----------+
# | objective(Value Short)     | 0.0211088 |
# +----------------------------+-----------+
# | objective(Vote Dissident)  | 0.180844  |
# +----------------------------+-----------+
# | objective(Vote Management) | 0.0124549 |
# +----------------------------+-----------+
# CPD of result:
# +----------------------------------+----------------------+-------------------------+----------------------+-----------------------+-----------------------+------------------------+---------------------------+----------------------------+
# | objective                        | objective(Board Add) | objective(Board Remove) | objective(ESG)       | objective(Merger)     | objective(Value Long) | objective(Value Short) | objective(Vote Dissident) | objective(Vote Management) |
# +----------------------------------+----------------------+-------------------------+----------------------+-----------------------+-----------------------+------------------------+---------------------------+----------------------------+
# | result(Dissident)                | 0.15659240124852009  | 0.19116360454943135     | 0.022522522522522525 | 0.1232827187274042    | 0.06410256410256408   | 0.16666666666666669    | 0.24497520229705036       | 0.16666666666666669        |
# +----------------------------------+----------------------+-------------------------+----------------------+-----------------------+-----------------------+------------------------+---------------------------+----------------------------+
# | result(Management)               | 0.22633731568184265  | 0.2961504811898513      | 0.4549549549549549   | 0.40093998553868404   | 0.6794871794871793    | 0.16666666666666669    | 0.3702688593056643        | 0.16666666666666669        |
# +----------------------------------+----------------------+-------------------------+----------------------+-----------------------+-----------------------+------------------------+---------------------------+----------------------------+
# | result(Pending)                  | 0.019169088365084488 | 0.06517935258092739     | 0.022522522522522525 | 0.01916124367317426   | 0.06410256410256408   | 0.16666666666666669    | 0.025711302531975986      | 0.16666666666666669        |
# +----------------------------------+----------------------+-------------------------+----------------------+-----------------------+-----------------------+------------------------+---------------------------+----------------------------+
# | result(Settled/Concessions Made) | 0.35652782262404475  | 0.12817147856517938     | 0.022522522522522525 | 0.19269703543022415   | 0.06410256410256408   | 0.16666666666666669    | 0.13847559383972854       | 0.16666666666666669        |
# +----------------------------------+----------------------+-------------------------+----------------------+-----------------------+-----------------------+------------------------+---------------------------+----------------------------+
# | result(Split)                    | 0.025368636314713162 | 0.02318460192475941     | 0.23873873873873874  | 0.0018076644974692698 | 0.06410256410256408   | 0.16666666666666669    | 0.04450535108326808       | 0.16666666666666669        |
# +----------------------------------+----------------------+-------------------------+----------------------+-----------------------+-----------------------+------------------------+---------------------------+----------------------------+
# | result(Withdrawn)                | 0.21600473576579488  | 0.2961504811898513      | 0.23873873873873874  | 0.2621113521330441    | 0.06410256410256408   | 0.16666666666666669    | 0.17606369094231272       | 0.16666666666666669        |
# +----------------------------------+----------------------+-------------------------+----------------------+-----------------------+-----------------------+------------------------+---------------------------+----------------------------+
# CPD of post_return:
# +--------------------------+---------------------+--------------------+--------------------+----------------------------------+--------------------+--------------------+
# | result                   | result(Dissident)   | result(Management) | result(Pending)    | result(Settled/Concessions Made) | result(Split)      | result(Withdrawn)  |
# +--------------------------+---------------------+--------------------+--------------------+----------------------------------+--------------------+--------------------+
# | post_return((-1.0, 0.0]) | 0.5083379655364091  | 0.5186552662261951 | 0.777533039647577  | 0.5076813655761024               | 0.4535603715170279 | 0.5188186095138526 |
# +--------------------------+---------------------+--------------------+--------------------+----------------------------------+--------------------+--------------------+
# | post_return((0.0, 1.0])  | 0.49166203446359086 | 0.4813447337738049 | 0.2224669603524229 | 0.49231863442389756              | 0.5464396284829721 | 0.4811813904861474 |
# +--------------------------+---------------------+--------------------+--------------------+----------------------------------+--------------------+--------------------+

# %% [markdown]
# # Appendix

# %%
df['1_year_post_date_total_return'].unique()
# Out:
# array([ 5.3903700e-04,            nan,  1.2344503e-03, ...,
#        -1.0526312e-03,  4.7933817e-04, -6.3291190e-05])

# %%
df['1_year_post_date_total_return'].describe()
# Out:
# count    7521.000000
# mean        0.000805
# std         0.015886
# min        -0.010000
# 25%        -0.002567
# 50%         0.000154
# 75%         0.002464
# max         1.240000
# Name: 1_year_post_date_total_return, dtype: float64

# %%
df.groupby(['campaign_objective_primary', 'proxy_campaign_winner_or_result']).campaign_id.count()
# Out:
# campaign_objective_primary                                proxy_campaign_winner_or_result
# Board Control                                             Dissident                          140
#                                                           Management                         151
#                                                           Pending                             17
#                                                           Settled/Concessions Made           226
#                                                           Split                               14
#                                                           Withdrawn                          190
# Board Representation                                      Dissident                          163
#                                                           Management                         287
#                                                           Pending                             20
#                                                           Settled/Concessions Made           464
#                                                           Split                               35
#                                                           Withdrawn                          228
# Enhance Corporate Governance                              Management                           2
#                                                           Split                                1
#                                                           Withdrawn                            1
# Hostile/Unsolicited Acquisition                           Settled/Concessions Made             1
# Maximize Shareholder Value                                Management                           1
# Remove Director(s), No Dissident Nominee to Fill Vacancy  Dissident                            9
#                                                           Management                          12
#                                                           Pending                              3
#                                                           Settled/Concessions Made             5
#                                                           Split                                1
#                                                           Withdrawn                           14
# Remove Officer(s)                                         Management                           2
#                                                           Settled/Concessions Made             1
# Vote Against a Management Proposal                        Dissident                           17
#                                                           Management                          26
#                                                           Settled/Concessions Made            11
#                                                           Split                                2
#                                                           Withdrawn                            6
# Vote For a Stockholder Proposal                           Dissident                           22
#                                                           Management                          33
#                                                           Pending                              4
#                                                           Settled/Concessions Made            11
#                                                           Split                                5
#                                                           Withdrawn                           22
# Vote/Activism Against a Merger                            Dissident                            7
#                                                           Management                          23
#                                                           Pending                              1
#                                                           Settled/Concessions Made            10
#                                                           Withdrawn                           15
# Name: campaign_id, dtype: int64

# %%
df.groupby(['campaign_objective_primary']).campaign_id.count().to_frame()
# Out:
#                                                     campaign_id
# campaign_objective_primary
# 13D Filer - No Publicly Disclosed Activism                 1256
# Board Control                                               790
# Board Representation                                       2131
# Enhance Corporate Governance                                270
# Hostile/Unsolicited Acquisition                             556
# Maximize Shareholder Value                                 2078
# Public Short Position/Bear Raid                             175
# Remove Director(s), No Dissident Nominee to Fil...           97
# Remove Officer(s)                                            49
# Support Dissident Group in Proxy Fight                      133
# Vote Against a Management Proposal                          362
# Vote For a Management Proposal/Support Management           103
# Vote For a Stockholder Proposal                            1009
# Vote/Activism Against a Merger                              562

# %%
df.groupby(['proxy_campaign_winner_or_result']).campaign_id.count().to_frame()
# Out:
#                                  campaign_id
# proxy_campaign_winner_or_result
# Dissident                                358
# Management                               537
# Pending                                   45
# Settled/Concessions Made                 729
# Split                                     58
# Withdrawn                                476

# %%
df.tail(1)
# Out:
#       campaign_id campaign_announcement_date  \
# 9570  1073549609C                 2018-12-06
#
#                                          campaign_title  \
# 9570  Del Frisco's Restaurant Group, Inc. / Engaged ...
#
#       campaign_objective_primary                   value_demand  \
# 9570  Maximize Shareholder Value  Review Strategic Alternatives
#
#               governance_demand  \
# 9570  Add Independent Directors
#
#                            activist_campaign_tactic  \
# 9570  Publicly Disclosed Letter to Board/Management
#
#       total_number_of_board_seats  number_of_board_seats_sought  \
# 9570                            0                             0
#
#      short_or_majority_or_full_slate  ... used_proxy_access_nomination_tactic  \
# 9570                             NaN  ...                                   0
#
#      used_publicly_disclosed_letter_to_board_or_management_tactic  \
# 9570                                                  1
#
#      used_take_action_by_written_consent_tactic  \
# 9570                                          0
#
#      used_tender_offer_launched_tactic used_tender_offer_stake_only_tactic  \
# 9570                                 0                                   0
#
#      used_threaten_proxy_fight_tactic used_unsolicited_offer_tactic  \
# 9570                                0                             0
#
#      used_withhold_vote_for_directors_tactic  \
# 9570                                       0
#
#       lagged_campaign_announcement_date past_return_successes
# 9570                         2018-08-15                   9.0
#
# [1 rows x 65 columns]

# %%
[print(x) for x in df.columns.tolist()];
# Out:
# campaign_id
# campaign_announcement_date
# campaign_title
# campaign_objective_primary
# value_demand
# governance_demand
# activist_campaign_tactic
# total_number_of_board_seats
# number_of_board_seats_sought
# short_or_majority_or_full_slate
# proxy_proposal
# glass_lewis_support
# iss_support
# activist_id
# activist_name
# activist_group
# first_trade_date
# last_trade_date
# ownership_pecent_on_announcements
# company_id
# company_name
# sector
# price_at_announcement
# ltm_eps_at_announcement
# earnings_yield_at_announcement
# current_entity_status
# current_entity_detail
# public_before_or_after_campaign_announcement
# poison_pill_in_force_prior_to_announcement
# poison_pill_adopted_in_response_to_campaign
# 18_months_pre_announcement_date
# 1_year_pre_announcement_date
# 6_months_pre_announcement_date
# 90_days_pre_announcement_date
# 18_months_pre_date_total_return
# 1_year_pre_date_total_return
# 6_months_pre_date_total_return
# 90_days_pre_date_total_return
# number_of_board_seats_gained
# proxy_campaign_winner_or_result
# activist_campaign_results
# 6_months_post_announcement_date
# 1_year_post_announcement_date
# 18_months_post_announcement_date
# 6_months_post_date_total_return
# 1_year_post_date_total_return
# 18_months_post_date_total_return
# used_call_special_meeting_tactic
# used_hostile_offer_tactic
# used_lawsuit_tactic
# used_letter_to_stockholders_tactic
# used_no_or_unknown_tactic
# used_nominate_slate_of_directors_tactic
# used_propose_binding_proposal_tactic
# used_propose_precatory_proposal_tactic
# used_proxy_access_nomination_tactic
# used_publicly_disclosed_letter_to_board_or_management_tactic
# used_take_action_by_written_consent_tactic
# used_tender_offer_launched_tactic
# used_tender_offer_stake_only_tactic
# used_threaten_proxy_fight_tactic
# used_unsolicited_offer_tactic
# used_withhold_vote_for_directors_tactic
# lagged_campaign_announcement_date
# past_return_successes
